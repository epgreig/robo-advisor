# %%
import pandas as pd
import numpy as np

# %%
path = '..\\Data\\'
# df = pd.read_csv(path + 'ETF_info_eq.csv').replace('--', np.nan)
# df_grp = pd.read_csv(path + 'ETF_info_eq_sect.csv').replace('--', np.nan) # e.g. sect or geo

# df = pd.read_csv(path + 'ETF_info_eq.csv').replace('--', np.nan)
# df_grp = pd.read_csv(path + 'ETF_info_eq_geo.csv').replace('--', np.nan)

# df = pd.read_csv(path + 'ETF_info_fi.csv').replace('--', np.nan)
# df_grp = pd.read_csv(path + 'ETF_info_fi_mat.csv').replace('--', np.nan)

df = pd.read_csv(path + 'ETF_info_fi_cad.csv').replace('--', np.nan)
df_grp = pd.read_csv(path + 'ETF_info_fi_cad_mat.csv').replace('--', np.nan)

# %%
def clean_float(df):
    
    sub_df = df.copy()
    
    for col in df.columns.values:
        try:
            sub_df[col] = sub_df[col].astype(float)
        except ValueError:
            pass
    
    return sub_df

# %%
df = clean_float(df)
df_grp = clean_float(df_grp)
grp_list = df_grp.drop(columns=['Name', 'Ticker']).columns.values

# %%
df = df.merge(df_grp, how='inner', on=['Ticker', 'Name'])

# %%
df.set_index('Ticker', inplace=True)

# %%
grp_list
# Out:
# array(['0-1 Yr', '1-3 Yrs', '3-5 Yrs', '5-7 Yrs', '7-10 Yrs', '+10 Yrs',
#        'Not Classified'], dtype=object)

# %%
grp_etfs = []
for grp in grp_list:
    
    sub_df = df[df[grp]>80].sort_values(by='30D Vol', ascending=False)
    
    if not sub_df.empty:
        etf_name = sub_df.index.values[0]
        grp_etfs.append((grp, etf_name))

grp_etfs = np.array(grp_etfs)

# %%
df.loc[grp_etfs[:,1]]
# Out:
#                                   Name    30D Vol  Class Assets\n(MLN USD)  \
# Ticker
# CMR CN  iShares Premium Money Market E   87935.00                286.99000
# RQI CN  RBC Target 2021 Corporate Bond    9658.47                 91.91500
# RQK CN  RBC Target 2023 Corporate Bond    2314.10                 65.53010
# RQN CN  RBC Target 2025 Corporate Bond    5439.40                  3.88835
# VLB CN  Vanguard Canadian Long-Term Bo   11803.00                 18.58610
# HPR CN  Horizons Active Preferred Shar  669712.00               1025.39000
#
#         Fund Assets\n(MLN USD)  YTD Return  YTD Class Flow\n(MLN USD)  \
# Ticker
# CMR CN               286.99000    0.758375                  30.986070
# RQI CN                91.91500    3.219980                  11.084600
# RQK CN                65.53010    5.036200                   6.428512
# RQN CN                 3.88835         NaN                   2.277757
# VLB CN                18.58610   11.331000                   9.914291
# HPR CN              1025.39000   -5.070740                 -77.088740
#
#         12M Yield  # of Holdings Primary Share Secondary Listing     0-1 Yr  \
# Ticker
# CMR CN    1.53768            8.0             Y                 N  100.00000
# RQI CN    2.76745           32.0             Y                 N    0.33030
# RQK CN    2.87103           21.0             Y                 N    0.25520
# RQN CN    2.16850           20.0             Y                 N    0.03715
# VLB CN    3.09693          307.0             Y                 N        NaN
# HPR CN    4.88663          290.0             Y                 N    1.30800
#
#         1-3 Yrs  3-5 Yrs  5-7 Yrs  7-10 Yrs  +10 Yrs  Not Classified
# Ticker
# CMR CN      NaN      NaN      NaN       NaN      NaN             NaN
# RQI CN    93.57      NaN   2.5720      3.53      NaN             NaN
# RQK CN      NaN    80.63      NaN     19.12      NaN             NaN
# RQN CN      NaN      NaN  99.9600       NaN      NaN             NaN
# VLB CN      NaN      NaN   0.0394       NaN  99.9600             NaN
# HPR CN      NaN      NaN      NaN       NaN   0.7563           97.94

# %%
df
# Out:
#                                     Name       30D Vol  \
# Ticker
# ZAG CN      BMO Aggregate Bond Index ETF  7.502990e+05
# XBB CN     iShares Core CanadianUniverse  5.302740e+05
# VAB CN    Vanguard Canadian Aggregate Bo  4.134140e+05
# XSB CN    iShares Core Canadian Short Te  2.311740e+05
# ZPR CN    BMO Laddered Preferred Share I  1.230640e+06
# XCB CN    iShares Canadian Corporate Bon  1.338720e+05
# HPR CN    Horizons Active Preferred Shar  6.697120e+05
# ZCS CN    BMO Short Corporate Bond Index  2.662120e+05
# ZIC CN    BMO Mid-Term US IG Corporate B  6.827220e+04
# CPD CN    iShares S&P/TSX Canadian Prefe  4.412290e+05
# PMIF CN        PIMCO Monthly Income Fund  3.010100e+05
# VSC CN    Vanguard Canadian Short-Term C  1.166230e+05
# ZFS CN    BMO Short Federal Bond Index E  3.052140e+05
# ZCM CN    BMO Mid Corporate Bond Index E  1.044030e+05
# CBO CN    iShares 1-5 Year Laddered Corp  9.000590e+04
# ZMU CN    BMO Mid-Term US IG Corporate B  1.895440e+05
# VSB CN    Vanguard Canadian Short-Term B  1.437410e+05
# XSH CN    iShares Core Canadian Short Te  1.368400e+05
# ZCPB CN      BMO Core Plus Bond Fund ETF  2.479640e+05
# ZJK CN    BMO High Yield US Corporate Bo  9.618570e+03
# PSB CN    Invesco 1-5 Year Laddered Inve  1.802960e+05
# ZFM CN    BMO Mid Federal Bond Index ETF  1.148020e+05
# XLB CN    iShares Core Canadian Long Ter  2.744080e+05
# XFR CN    iShares Floating Rate Index ET  1.781720e+05
# RPF CN    RBC Canadian Preferred Share E  1.518380e+05
# ZFL CN    BMO Long Federal Bond Index ET  1.662300e+05
# HFR CN     Horizons Active Floating Rate  2.982650e+05
# ZHY CN    BMO High Yield US Corporate Bo  1.665270e+05
# CLF CN    iShares 1-5 Year Laddered Gove  1.024260e+05
# ZDB CN       BMO Discount Bond Index ETF  6.399690e+04
# ...                                  ...           ...
# DCS CN    Desjardins Canadian Short Term  6.060330e+02
# QCB CN    Mackenzie Canadian All Corpora  6.140000e+02
# ZHP CN     BMO US Preferred Share Hedged  4.762900e+03
# DCP CN     Desjardins Canadian Preferred  7.839670e+02
# IGB CN    Purpose Managed Duration Inves  3.113630e+03
# FLSL CN   Franklin Liberty Senior Loan E  2.589330e+02
# MCSB CN    Mackenzie Canadian Short Term  9.143370e+03
# DCC CN    Desjardins 1-5 year Laddered C  1.050000e+02
# TPRF CN    TD Active Preferred Share ETF  3.153640e+04
# FLUI CN   Franklin Liberty US Investment  1.650000e+01
# RUSB CN   RBC Short Term US Corporate Bo  1.288700e+03
# TIME CN   Evolve Active Short Duration B  3.007330e+02
# RQN CN    RBC Target 2025 Corporate Bond  5.439400e+03
# ONEB CN   ONE North American Core Plus B  3.073370e+03
# QSB CN     Mackenzie Canadian Short-Term  7.573330e+01
# PGB CN     Invesco 1-5 Year Laddered All  3.053330e+01
# PLDI CN   Pimco Low Duration Monthly Inc  6.164670e+03
# TCSB CN   TD Select Short Term Corporate  3.450890e+04
# RMBO CN   RBC 6-10 Year Laddered Canadia  1.001870e+03
# DCU CN    Desjardins Canadian Universe B  2.200330e+02
# TUSB CN   TD Select U.S. Short Term Corp  1.243670e+02
# FSD/A CN  First Trust Short Duration Hig  2.370330e+02
# RCDB CN   RBC Canadian Discount Bond ETF           NaN
# SFIX CN    Scotia Strategic Fixed Income  9.167000e+02
# IEMB CN   IA Clarington Emerging Markets  6.526670e+03
# IGLB CN   IA Clarington Global Bond Fund  7.664670e+03
# ICPB CN   IA Clarington Core Plus Bond F  4.839600e+03
# BPRF CN   Brompton Flaherty & Crumrine I  6.765100e+03
# XSTB CN   Ishares ESG Canadian Short Ter  5.016000e+02
# XSAB CN   Ishares ESG Canadian Aggregate  4.275300e+03
#
#           Class Assets\n(MLN USD)  Fund Assets\n(MLN USD)  YTD Return  \
# Ticker
# ZAG CN                3443.770000              3443.77000    6.048460
# XBB CN                2215.730000              2215.73000    6.488660
# VAB CN                1697.870000              1697.87000    6.232540
# XSB CN                1580.640000              1580.64000    2.814520
# ZPR CN                1413.370000              1413.37000   -4.574850
# XCB CN                1223.450000              1223.45000    6.661040
# HPR CN                1025.390000              1025.39000   -5.070740
# ZCS CN                1002.640000              1002.64000    4.012170
# ZIC CN                 953.718000               953.71800    6.857720
# CPD CN                 943.140000               943.14000   -3.308130
# PMIF CN                896.796000               917.80500    4.904450
# VSC CN                 844.980000               844.98000    3.859310
# ZFS CN                 812.849000               812.84900    2.196700
# ZCM CN                 800.729000               800.72900    7.222670
# CBO CN                 794.889000               794.88900    3.608400
# ZMU CN                 794.584000               794.58400    8.065820
# VSB CN                 778.008000               778.00800    2.846850
# XSH CN                 769.832000               769.83200    4.067380
# ZCPB CN                620.315000               620.31500         NaN
# ZJK CN                 577.376000               577.37600    7.753440
# PSB CN                 576.812000               576.81200    3.389390
# ZFM CN                 562.635000               562.63500    4.687380
# XLB CN                 547.489000               547.48900   11.931200
# XFR CN                 542.841000               542.84100    1.259140
# RPF CN                 542.115000               542.11500   -6.016310
# ZFL CN                 534.961000               534.96100    9.376530
# HFR CN                 531.896000               531.89600    2.528390
# ZHY CN                 522.446000               522.44600    8.785310
# CLF CN                 520.441000               520.44100    2.489140
# ZDB CN                 509.175000               509.17500    6.103670
# ...                           ...                     ...         ...
# DCS CN                  10.251700                10.25170    2.521990
# QCB CN                   9.199780                 9.19978         NaN
# ZHP CN                   8.906680                 8.90668    9.966060
# DCP CN                   8.746030                 8.74603    0.011689
# IGB CN                   8.740830                 8.74083    2.328200
# FLSL CN                  8.588600                 8.58860    5.524660
# MCSB CN                  7.499930                 7.49993    3.180470
# DCC CN                   7.297230                 7.29723         NaN
# TPRF CN                  6.675600                 6.67560   -5.350950
# FLUI CN                  6.183290                 6.18329         NaN
# RUSB CN                  5.649430               133.16500    2.570490
# TIME CN                  4.288920                 5.45345    3.705270
# RQN CN                   3.888350                 3.88835         NaN
# ONEB CN                  3.732350                 3.73235    4.083710
# QSB CN                   3.028650                 3.02865         NaN
# PGB CN                   3.017060                 3.01706    2.457540
# PLDI CN                  2.273180                 2.27318         NaN
# TCSB CN                  1.678590                 1.67859    4.516440
# RMBO CN                  1.547150                 2.60193    6.923520
# DCU CN                   1.519330                 2.03940         NaN
# TUSB CN                  1.169490                 3.51330         NaN
# FSD/A CN                 0.915256                 1.36500         NaN
# RCDB CN                       NaN                 2.23818         NaN
# SFIX CN                       NaN                 1.16069    6.144740
# IEMB CN                       NaN                     NaN         NaN
# IGLB CN                       NaN                     NaN         NaN
# ICPB CN                       NaN                     NaN    3.768890
# BPRF CN                       NaN                     NaN         NaN
# XSTB CN                       NaN                     NaN         NaN
# XSAB CN                       NaN                     NaN         NaN
#
#           YTD Class Flow\n(MLN USD)  12M Yield  # of Holdings Primary Share  \
# Ticker
# ZAG CN                   700.834000   2.863380         1084.0             Y
# XBB CN                   352.358400   2.772740         1288.0             Y
# VAB CN                   449.994300   2.655120          949.0             Y
# XSB CN                   -48.899280   2.355700          492.0             Y
# ZPR CN                   172.435800   5.294740          200.0             Y
# XCB CN                   -39.676430   2.934130          896.0             Y
# HPR CN                   -77.088740   4.886630          290.0             Y
# ZCS CN                   -95.984650   2.843140          372.0             Y
# ZIC CN                   -67.422540   3.517670          558.0             Y
# CPD CN                   -55.619570   5.046340          241.0             Y
# PMIF CN                  274.189500   3.373010            NaN             Y
# VSC CN                    10.971070   2.690630          300.0             Y
# ZFS CN                    64.126700   1.706130           37.0             Y
# ZCM CN                   -51.108070   3.203120          174.0             Y
# CBO CN                   -44.383440   2.691970          301.0             Y
# ZMU CN                   -59.562620   3.612040            1.0             Y
# VSB CN                    69.635520   2.256090          405.0             Y
# XSH CN                   101.799500   2.759150          408.0             Y
# ZCPB CN                  582.379300   2.373420          211.0             Y
# ZJK CN                  -277.846600   5.483090          826.0             Y
# PSB CN                   -40.377420   3.122910           45.0             Y
# ZFM CN                   103.889000   1.972420           20.0             Y
# XLB CN                   143.370200   3.231610          482.0             Y
# XFR CN                   -50.061210   1.856080           35.0             Y
# RPF CN                   -44.634740   4.987090          189.0             Y
# ZFL CN                   300.483400   2.833510           15.0             Y
# HFR CN                    -0.146111   2.556570          233.0             Y
# ZHY CN                  -260.524500   5.988330            4.0             Y
# CLF CN                    -1.228729   2.592730           39.0             Y
# ZDB CN                     4.982106   2.062040          152.0             Y
# ...                             ...        ...            ...           ...
# DCS CN                     0.000000   2.589400          340.0             Y
# QCB CN                    -0.024083   2.754410          152.0             Y
# ZHP CN                    -0.028573   5.219550            1.0             Y
# DCP CN                     2.705750   5.288520          197.0             Y
# IGB CN                    87.749740   2.735500            2.0             Y
# FLSL CN                    0.720526   6.341850           40.0             Y
# MCSB CN                    2.991427   2.847800           63.0             Y
# DCC CN                     0.000000   3.059660          122.0             Y
# TPRF CN                   22.225640   2.269500           98.0             Y
# FLUI CN                    0.000000   3.575310           81.0             Y
# RUSB CN                   -2.398609   2.327940          247.0             Y
# TIME CN                    1.450312   4.396750            NaN             Y
# RQN CN                     2.277757   2.168500           20.0             Y
# ONEB CN                   -3.955400   1.514570           32.0             Y
# QSB CN                    -3.020920   2.032380           51.0             Y
# PGB CN                    -5.248098   2.701040           46.0             Y
# PLDI CN                    1.499919   0.491695            NaN             Y
# TCSB CN                    2.172677   1.324870           85.0             Y
# RMBO CN                   -9.061325   2.950580           58.0             Y
# DCU CN                     0.000000   2.768780          467.0             Y
# TUSB CN                    0.000000   1.955420           76.0             Y
# FSD/A CN                  -0.017545   4.952380           84.0             Y
# RCDB CN                    0.747022        NaN           67.0             Y
# SFIX CN                   -0.385777   2.621450            NaN             Y
# IEMB CN                    0.000000   2.763380            NaN             Y
# IGLB CN                    0.000000   2.416190            NaN             Y
# ICPB CN                    0.000000   1.404920            NaN             Y
# BPRF CN                    1.130695   3.032150           27.0             Y
# XSTB CN                    0.005480   0.396825          122.0             Y
# XSAB CN                    1.526075   0.452775          136.0             Y
#
#          Secondary Listing     0-1 Yr  1-3 Yrs  3-5 Yrs  5-7 Yrs  7-10 Yrs  \
# Ticker
# ZAG CN                   N        NaN      NaN      NaN      NaN       NaN
# XBB CN                   N        NaN      NaN      NaN      NaN       NaN
# VAB CN                   N   0.000019   24.580    18.04   10.360    12.750
# XSB CN                   N        NaN      NaN      NaN      NaN       NaN
# ZPR CN                   N        NaN      NaN      NaN      NaN       NaN
# XCB CN                   N        NaN      NaN      NaN      NaN       NaN
# HPR CN                   N   1.308000      NaN      NaN      NaN       NaN
# ZCS CN                   N        NaN      NaN      NaN      NaN       NaN
# ZIC CN                   N        NaN      NaN      NaN      NaN       NaN
# CPD CN                   N        NaN      NaN      NaN      NaN       NaN
# PMIF CN                  N        NaN      NaN      NaN      NaN       NaN
# VSC CN                   N        NaN   51.050    38.29    4.179     6.127
# ZFS CN                   N        NaN      NaN      NaN      NaN       NaN
# ZCM CN                   N        NaN      NaN      NaN      NaN       NaN
# CBO CN                   N  11.860000   38.880    33.73    8.455     4.839
# ZMU CN                   N        NaN      NaN      NaN      NaN       NaN
# VSB CN                   N   0.000051   56.110    40.33    1.343     2.102
# XSH CN                   N        NaN      NaN      NaN      NaN       NaN
# ZCPB CN                  N   4.614000   15.650    11.91   16.380    26.800
# ZJK CN                   N        NaN      NaN      NaN      NaN       NaN
# PSB CN                   N        NaN      NaN      NaN      NaN       NaN
# ZFM CN                   N        NaN      NaN      NaN      NaN       NaN
# XLB CN                   N        NaN      NaN      NaN      NaN       NaN
# XFR CN                   N        NaN      NaN      NaN      NaN       NaN
# RPF CN                   N   1.998000      NaN      NaN      NaN       NaN
# ZFL CN                   N        NaN      NaN      NaN      NaN       NaN
# HFR CN                   N  11.990000   29.440    31.64   14.800     8.186
# ZHY CN                   N        NaN      NaN      NaN      NaN       NaN
# CLF CN                   N  19.800000   40.050    40.16      NaN       NaN
# ZDB CN                   N        NaN      NaN      NaN      NaN       NaN
# ...                    ...        ...      ...      ...      ...       ...
# DCS CN                   N   5.093000   53.270    38.37    1.489     1.693
# QCB CN                   N        NaN      NaN      NaN      NaN       NaN
# ZHP CN                   N        NaN      NaN      NaN      NaN       NaN
# DCP CN                   N   0.394100      NaN      NaN      NaN       NaN
# IGB CN                   N        NaN      NaN      NaN      NaN       NaN
# FLSL CN                  N   8.469000    4.718    41.41   45.400       NaN
# MCSB CN                  N        NaN   12.820    44.22   23.470     8.754
# DCC CN                   N   2.570000   40.780    31.36   19.580     4.364
# TPRF CN                  N   0.024110      NaN      NaN      NaN       NaN
# FLUI CN                  N   4.712000    8.890    24.97   13.170    16.190
# RUSB CN                  N   3.905000   47.230    41.63    7.243       NaN
# TIME CN                  N        NaN      NaN      NaN      NaN       NaN
# RQN CN                   N   0.037150      NaN      NaN   99.960       NaN
# ONEB CN                  N        NaN      NaN      NaN      NaN       NaN
# QSB CN                   N        NaN      NaN      NaN      NaN       NaN
# PGB CN                   N        NaN   39.490    40.55   19.960       NaN
# PLDI CN                  N        NaN      NaN      NaN      NaN       NaN
# TCSB CN                  N  10.440000   37.370    43.08    9.119       NaN
# RMBO CN                  N   0.302600      NaN      NaN   33.650    62.030
# DCU CN                   N   2.154000   23.790    16.94   11.100    12.440
# TUSB CN                  N  12.680000   46.270    32.19    8.859       NaN
# FSD/A CN                 N        NaN      NaN      NaN      NaN       NaN
# RCDB CN                  N   5.394000   53.960    31.55    7.593     1.511
# SFIX CN                  N        NaN      NaN      NaN      NaN       NaN
# IEMB CN                  N        NaN      NaN      NaN      NaN       NaN
# IGLB CN                  N        NaN      NaN      NaN      NaN       NaN
# ICPB CN                  N        NaN      NaN      NaN      NaN       NaN
# BPRF CN                  N        NaN      NaN      NaN      NaN       NaN
# XSTB CN                  N   3.559000   50.810    37.58    3.488     4.009
# XSAB CN                  N   1.246000   18.380    20.33   10.960    14.950
#
#            +10 Yrs  Not Classified
# Ticker
# ZAG CN         NaN             NaN
# XBB CN         NaN             NaN
# VAB CN    34.27000             NaN
# XSB CN         NaN             NaN
# ZPR CN         NaN             NaN
# XCB CN         NaN             NaN
# HPR CN     0.75630         97.9400
# ZCS CN         NaN             NaN
# ZIC CN         NaN             NaN
# CPD CN         NaN             NaN
# PMIF CN        NaN             NaN
# VSC CN     0.35280             NaN
# ZFS CN         NaN             NaN
# ZCM CN         NaN             NaN
# CBO CN     2.24600             NaN
# ZMU CN         NaN             NaN
# VSB CN     0.10840             NaN
# XSH CN         NaN             NaN
# ZCPB CN   28.75000          0.7561
# ZJK CN         NaN             NaN
# PSB CN         NaN             NaN
# ZFM CN         NaN             NaN
# XLB CN         NaN             NaN
# XFR CN         NaN             NaN
# RPF CN         NaN         98.0000
# ZFL CN         NaN             NaN
# HFR CN     3.84200          0.1046
# ZHY CN         NaN             NaN
# CLF CN         NaN             NaN
# ZDB CN         NaN             NaN
# ...            ...             ...
# DCS CN     0.08768             NaN
# QCB CN         NaN             NaN
# ZHP CN         NaN             NaN
# DCP CN         NaN         99.6100
# IGB CN         NaN        100.0000
# FLSL CN        NaN             NaN
# MCSB CN    1.43500          9.3020
# DCC CN     1.35400             NaN
# TPRF CN        NaN         99.9800
# FLUI CN   32.07000             NaN
# RUSB CN        NaN             NaN
# TIME CN        NaN             NaN
# RQN CN         NaN             NaN
# ONEB CN        NaN             NaN
# QSB CN         NaN             NaN
# PGB CN         NaN             NaN
# PLDI CN        NaN             NaN
# TCSB CN        NaN             NaN
# RMBO CN    4.01400             NaN
# DCU CN    33.57000             NaN
# TUSB CN        NaN             NaN
# FSD/A CN       NaN             NaN
# RCDB CN        NaN             NaN
# SFIX CN        NaN        100.0000
# IEMB CN        NaN             NaN
# IGLB CN        NaN             NaN
# ICPB CN        NaN             NaN
# BPRF CN   99.78000          0.2174
# XSTB CN    0.55400             NaN
# XSAB CN   34.13000             NaN
#
# [184 rows x 17 columns]
