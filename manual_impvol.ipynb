# %%
import numpy as np
import pandas as pd

# %%
price_df = pd.read_csv('..\\Data\\ETF_price_data.csv')
price_df = price_df.set_index('Dates')

# %%
for i,date in enumerate(price_df.index[28:]):
    print(i, date)
# Out:
# 0 2006-05-31
# 1 2006-06-30
# 2 2006-07-31
# 3 2006-08-31
# 4 2006-09-29
# 5 2006-10-31
# 6 2006-11-30
# 7 2006-12-29
# 8 2007-01-31
# 9 2007-02-28
# 10 2007-03-30
# 11 2007-04-30
# 12 2007-05-31
# 13 2007-06-29
# 14 2007-07-31
# 15 2007-08-31
# 16 2007-09-28
# 17 2007-10-31
# 18 2007-11-30
# 19 2007-12-31
# 20 2008-01-31
# 21 2008-02-29
# 22 2008-03-31
# 23 2008-04-30
# 24 2008-05-30
# 25 2008-06-30
# 26 2008-07-31
# 27 2008-08-29
# 28 2008-09-30
# 29 2008-10-31
# 30 2008-11-28
# 31 2008-12-31
# 32 2009-01-30
# 33 2009-02-27
# 34 2009-03-31
# 35 2009-04-30
# 36 2009-05-29
# 37 2009-06-30
# 38 2009-07-31
# 39 2009-08-31
# 40 2009-09-30
# 41 2009-10-30
# 42 2009-11-30
# 43 2009-12-31
# 44 2010-01-29
# 45 2010-02-26
# 46 2010-03-31
# 47 2010-04-30
# 48 2010-05-31
# 49 2010-06-30
# 50 2010-07-30
# 51 2010-08-31
# 52 2010-09-30
# 53 2010-10-29
# 54 2010-11-30
# 55 2010-12-31
# 56 2011-01-31
# 57 2011-02-28
# 58 2011-03-31
# 59 2011-04-29
# 60 2011-05-31
# 61 2011-06-30
# 62 2011-07-29
# ...

# %%
data = np.zeros((157,2,9))

# %%
data[0,:,:] = np.array([[31.85, 24.32, 19.12, 16.49, 13.82, 11.59, 10.18, 10.37, 12.92],
                        [28.43, 21.44, 17.74, 15.90, 14.09, 12.46, 11.02, 9.42, 9.74]])

# %%
data[1,:,:] = np.array([[27.14, 20.69, 16.08, 13.76, 11.60, 9.82, 9.61, 10.69, 12.72],
                        [24.85, 19.01, 15.86, 14.17, 12.54, 11.09, 9.89, 8.95, 10.36]])

# %%
data[2,:,:] = np.array([[29.51, 21.72, 16.79, 14.54, 12.43, 10.52, 9.94, 10.37, 11.58],
                        [25.54, 19.70, 16.49, 14.89, 13.30, 11.71, 10.38, 10.00, 11.02]])

# %%
data[3,:,:] = np.array([[25.95, 19.73, 14.54, 12.3, 10.24, 8.8, 8.86, 9.89, 11.85],
                        [22.96, 17.75, 14.44, 12.87, 11.29, 9.91, 8.96, 8.76, 9.78]])

# %%
data[4,:,:] = np.array([[23.5, 18.94, 14.48, 12.24, 10.09, 8.40, 8.47, 10.76, 13.84],
                        [23.12, 17.93, 14.59, 12.95, 11.39, 9.9, 8.74, 8.95, 10.14]])

# %%
data[5,:,:] = np.array([[22.92, 17.02, 13.24, 11.36, 9.8, 8.8, 9.12, 11.27, 13.61],
                        [20.74, 15.8, 12.98, 11.62, 10.35, 9.24, 8.48, 8.77, 9.8]])

# %%
data[6,:,:] = np.array([[25.43, 19.06, 13.93, 11.46, 9.40, 8.05, 7.69, 8.44, 10.73],
                        [22.60, 16.69, 13.44, 11.88, 10.42, 9.18, 8.18, 7.86, 8.89]])

# %%
data[7,:,:] = np.array([[25.1, 18.83, 13.53, 11.23, 9.03, 7.44, 7.33, 8.37, 10.63],
                        [22.28, 17.21, 13.9, 12.32, 10.76, 9.31, 8.16, 7.58, 9.68]])

# %%
data[8,:,:] = np.array([[23.15, 17.58, 13.44, 11.25, 9.06, 7.35, 7.42, 9.39, 12.82],
                        [20.68, 16.15, 13.02, 11.46, 9.89, 8.45, 7.33, 7.14, 9.58]])

# %%
data[9,:,:] = np.array([[32.43, 23.98, 18.79, 16.25, 13.97, 12.17, 11.18, 10.71, 13.68],
                        [25.78, 19.98, 16.87, 15.22, 13.60, 12.12, 10.78, 9.55, 10.60]])

# %%
data[10,:,:] = np.array([[29.65, 22.22, 17.63, 15.13, 12.73, 10.57, 9.50, 10.44, 12.27],
                        [26.47, 20.33, 16.87, 15.03, 13.24, 11.54, 9.97, 8.67, 9.54]])

# %%
data[11,:,:] = np.array([[30.1, 22.96, 17.35, 14.79, 12.49, 10.63, 9.87, 9.74, 9.91],
                        [26.69, 19.65, 16.04, 14.29, 12.62, 11.12, 9.95, 9.19, 10.00]])

# %%
data[12,:,:] = np.array([[29.40, 21.43, 15.97, 13.30, 10.95, 9.23, 8.66, 8.84, 11.35],
                        [24.96, 18.68, 15.26, 13.54, 11.89, 10.44, 9.32, 8.64, 9.50]])

# %%
data[13,:,:] = np.array([[26.68, 22.88, 19.02, 16.82, 14.43, 12.31, 10.69, 10.81, 13.79],
                        [26.74, 21.75, 18.66, 16.99, 15.24, 13.63, 12.24, 10.5, 11.48]])

# %%
data[14,:,:] = np.array([[36.72, 30.05, 26.03, 23.77, 21.42, 19.16, 17.09, 15.03, 16.37],
                        [32.45, 27.41, 24.27, 22.56, 20.83, 19.17, 17.60, 14.87, 13.61]])

# %%
data[15,:,:] = np.array([[36.34, 30.01, 25.93, 23.40, 20.73, 18.15, 15.88, 13.86, 15.26],
                        [33.53, 28.47, 24.98, 23.01, 20.98, 19.03, 17.17, 14.14, 12.99]])

# %%
data[16,:,:] = np.array([[32.44, 25.04, 20.71, 18.36, 15.97, 13.62, 11.83, 11.69, 14.85],
                        [29.33, 23.72, 20.51, 18.76, 16.94, 15.20, 13.55, 11.06, 11.39]])

# %%
data[17,:,:] = np.array([[31.19, 24.67, 20.86, 18.78, 16.45, 14.07, 12.23, 11.54, 14.46],
                        [29.53, 23.87, 20.82, 19.09, 17.28, 15.55, 13.96, 11.75, 12.1]])

# %%
data[18,:,:] = np.array([[33.34, 27.61, 25.19, 23.53, 21.65, 19.61, 17.54, 15.05, 16.19],
                        [31.96, 28.04, 25.39, 23.86, 22.28, 20.70, 19.10, 16.13, 14.27]])

# %%
data[19,:,:] = np.array([[30.2, 25.83, 22.73, 20.95, 18.96, 16.95, 15.08, 14.1, 15.67],
                        [30.35, 26.32, 23.76, 22.25, 20.63, 19.02, 17.46, 14.73, 13.39]])

# %%
data[20,:,:] = np.array([[37.97, 31.19, 27.94, 26.04, 24.01, 21.96, 19.99, 17.85, 18.67],
                        [33.94, 29.3, 26.65, 25.15, 23.6, 22.07, 20.6, 17.8, 15.84]])

# %%
data[21,:,:] = np.array([[34.31, 30.34, 27.81, 26.37, 24.79, 23.09, 21.3, 18.94, 19.95],
                        [34.73, 30.44, 28.04, 26.7, 25.26, 23.79, 22.36, 19.72, 17.27]])

# %%
data[22,:,:] = np.array([[35.46, 29.84, 27.33, 25.76, 24.02, 22.19, 20.36, 17.74, 17.7],
                        [32.78, 29.12, 26.9, 25.6, 24.24, 22.87, 21.52, 18.89, 16.61]])

# %%
data[23,:,:] = np.array([[32.82, 25.68, 22.41, 20.73, 19.05, 17.4, 15.93, 14.5, 15.48],
                        [30, 24.71, 22.18, 20.82, 19.47, 18.14, 16.82, 14.74, 14.19]])

# %%
data[24,:,:] = np.array([[29.59, 22.97, 19.34, 17.61, 15.92, 14.26, 12.85, 12.64, 14.58],
                        [28.36, 23, 20.36, 18.98, 17.55, 16.13, 14.72, 12.54, 12.55]])

# %%
data[25,:,:] = np.array([[35.16, 28.63, 25.42, 23.8, 22.09, 20.46, 18.99, 17.26, 17.61],
                        [32.61, 27.8, 25.35, 23.97, 22.53, 21.11, 19.76, 17.22, 15.02]])

# %%
data[26,:,:] = np.array([[32.19, 27.35, 24.39, 22.85, 21.27, 19.75, 18.35, 16.67, 17.4],
                        [30.2, 26.18, 24.01, 22.82, 21.6, 20.39, 19.23, 17.13, 15.76]])

# %%
data[27,:,:] = np.array([[31.91, 24.69, 21.89, 20.53, 19.12, 17.71, 16.52, 15.35, 16.29],
                        [29.11, 24.78, 22.77, 21.66, 20.54, 19.42, 18.34, 16.54, 15.97]])

# %%
data[28,:,:] = np.array([[49.74, 43.75, 40.59, 39, 37.45, 35.93, 34.43, 31.66, 29.66],
                        [42.97, 38.27, 35.8, 34.54, 33.29, 32.07, 30.88, 28.63, 25.37]])

# %%
data[29,:,:] = np.array([[71.88, 61.17, 56.32, 54.05, 51.79, 49.5, 47.16, 42.66, 37.71],
                        [64.46, 56.43, 52.72, 50.97, 49.28, 47.6, 45.91, 42.43, 35.81]])

# %%
data[30,:,:] = np.array([[65.71, 57.69, 53.96, 52.06, 50.16, 48.32, 46.59, 43.48, 38.23],
                        [61.6, 55.11, 52.04, 50.59, 49.2, 47.83, 46.48, 43.8, 39.08]])

# %%
data[31,:,:] = np.array([[50.32, 41.89, 38.1, 36.28, 34.58, 32.99, 31.53, 29.1, 26.43],
                        [47.68, 41.98, 39.07, 37.62, 36.2, 34.84, 33.53, 30.93, 26.36]])

# %%
data[32,:,:] = np.array([[57.24, 47.53, 43.32, 41.34, 39.44, 37.59, 35.82, 33.05, 31.21],
                        [52.53, 45.9, 42.71, 41.13, 39.59, 38.12, 36.71, 34.02, 29.84]])

# %%
data[33,:,:] = np.array([[56.9, 49.15, 45.76, 44.03, 42.31, 40.64, 39.1, 36.55, 33.02],
                        [52.61, 46.5, 43.58, 42.14, 40.73, 39.39, 38.12, 35.86, 32.13]])

# %%
data[34,:,:] = np.array([[55.32, 46.82, 43.47, 42.06, 40.79, 39.61, 38.52, 36.76, 34.95],
                        [51.42, 46, 43.51, 42.35, 41.25, 40.22, 39.25, 37.44, 34.45]])

# %%
data[35,:,:] = np.array([[48.77, 38.99, 35.34, 33.71, 32.18, 30.81, 29.68, 28.25, 27.9],
                        [43.36, 37.97, 35.38, 43.15, 32.96, 31.82, 30.73, 28.77, 26.37]])

# %%
data[36,:,:] = np.array([[25.7, 35.17, 30.77, 28.79, 26.97, 25.3, 23.89, 22.22, 22.02],
                        [39.74, 33.43, 30.46, 28.98, 27.59, 26.32, 25.13, 22.91, 20.33]])

# %%
data[37,:,:] = np.array([[42.73, 33.41, 29.18, 26.99, 24.93, 23, 21.19, 18.64, 18.26],
                        [36.91, 30.71, 27.58, 26.07, 24.65, 23.31, 22.03, 19.76, 17.97]])

# %%
data[38,:,:] = np.array([[39.51, 30.39, 26.61, 24.9, 23.42, 22.18, 21.22, 20.17, 19.83],
                        [35.24, 28.92, 26.11, 24.84, 23.71, 22.71, 21.86, 20.61, 19.5]])

# %%
data[39,:,:] = np.array([[40.55, 29.71, 25.24, 23.51, 22.06, 20.94, 20.22, 19.58, 20.18],
                        [36.5, 30, 26.98, 25.61, 24.38, 23.27, 22.25, 20.6, 19.29]])

# %%
data[40,:,:] = np.array([[40.5, 30.34, 25.81, 23.78, 21.99, 20.5, 19.46, 18.49, 19.27],
                        [35.15, 28.73, 25.55, 24.06, 22.69, 21.44, 20.31, 18.67, 17.62]])

# %%
data[41,:,:] = np.array([[46.45, 35.42, 30.11, 27.75, 25.69, 23.87, 22.36, 20.92, 21.59],
                        [38.76, 31.69, 28.21, 26.66, 25.25, 23.94, 22.71, 20.81, 19.84]])

# %%
data[42,:,:] = np.array([[40.39, 29.52, 24.47, 22.23, 20.33, 18.87, 17.94, 17.24, 18.24],
                        [34.53, 27.55, 24.3, 22.79, 21.42, 20.23, 19.22, 17.79, 16.55]])

# %%
data[43,:,:] = np.array([[39, 28, 22.15, 19.77, 17.74, 16.26, 15.61, 15.74, 18.39],
                        [33.11, 25.87, 22.42, 20.84, 19.4, 18.05, 16.87, 15.7, 15.21]])

# %%
data[44,:,:] = np.array([[38.98, 29.61, 25.27, 23.08, 21.04, 19.34, 18.21, 17.11, 17.62],
                        [35.25, 28.38, 24.98, 23.23, 21.61, 20.18, 18.92, 17.05, 15.72]])

# %%
data[45,:,:] = np.array([[35.77, 26, 21.15, 18.74, 16.36, 14.56, 13.78, 15.26, 18.24],
                        [31.08, 24.39, 21.03, 19.35, 17.66, 16.18, 15.06, 13.83, 14.97]])

# %%
data[46,:,:] = np.array([[30.38, 21.83, 17.61, 15.52, 13.45, 11.59, 10.1, 9.18, 8.66],
                        [28.05, 21.58, 18.41, 16.83, 15.27, 13.89, 12.79, 11.3, 10.15]])

# %%
data[47,:,:] = np.array([[38.11, 28.06, 23.08, 20.6, 18.13, 15.94, 14.22, 12.12, 12.44],
                        [33.97, 26.27, 22.49, 20.61, 18.76, 17.13, 15.85, 14.25, 14.32]])

# %%
data[48,:,:] = np.array([[47.16, 36.89, 31.61, 28.94, 26.24, 23.82, 21.87, 19.43, 20.85],
                        [42.59, 34.46, 30.33, 28.27, 26.2, 24.26, 22.49, 19.42, 15.04]])

# %%
data[49,:,:] = np.array([[47.85, 38.99, 34.37, 32, 29.6, 27.38, 25.5, 22.67, 20.75],
                        [44.6, 37.15, 33.37, 31.48, 29.58, 27.77, 26.08, 23.07, 18.26]])

# %%
data[50,:,:] = np.array([[37.15, 28.29, 24.1, 22.1, 20.16, 18.5, 17.24, 15.96, 16.52],
                        [35.33, 28.4, 25, 23.31, 21.64, 20.09, 18.73, 16.48, 14.01]])

# %%
data[51,:,:] = np.array([[38.21, 30.81, 27.19, 25.4, 23.62, 22, 20.63, 18.69, 18.58],
                        [36.91, 30.94, 27.92, 26.41, 24.88, 23.41, 22.02, 19.46, 15.26]])

# %%
data[52,:,:] = np.array([[37.04, 28.16, 23.92, 21.92, 20, 18.38, 17.22, 16.3, 16.72],
                        [34.76, 28.01, 24.7, 23.06, 21.43, 19.95, 18.68, 16.73, 14.57]])

# %%
data[53,:,:] = np.array([[33.68, 25.92, 22.18, 20.39, 18.65, 17.17, 16.08, 15.12, 16.27],
                        [30.85, 24.9, 22.03, 20.62, 19.21, 17.91, 16.76, 14.84, 12.26]])

# %%
data[54,:,:] = np.array([[36.81, 28.4, 24.2, 22.1, 20.01, 18.16, 16.75, 15.3, 16.34],
                        [33.56, 26.93, 23.7, 22.11, 20.53, 19.05, 17.74, 15.53, 13.1]])

# %%
data[55,:,:] = np.array([[32.29, 23.67, 19.37, 17.33, 15.36, 13.77, 12.86, 13.22, 13.43],
                        [29.71, 23.05, 19.87, 18.32, 16.78, 15.39, 14.22, 12.43, 11.35]])

# %%
data[56,:,:] = np.array([[37.69, 26.34, 20.77, 18.04, 15.35, 13.21, 11.96, 12.89, 14.54],
                        [31.1, 23.26, 19.56, 17.76, 15.98, 14.38, 13.02, 10.77, 9.5]])

# %%
data[57,:,:] = np.array([[35.9, 25.3, 19.98, 17.37, 14.8, 12.66, 11.23, 10.49, 11.23],
                        [30.85, 23.16, 19.42, 17.57, 15.72, 14.03, 12.58, 10.24, 8.67]])

# %%
data[58,:,:] = np.array([[35.1, 24.6, 19.45, 16.65, 14.6, 12.62, 11.86, 13.88, 18.65],
                        [29.36, 22.78, 19.24, 17.45, 15.67, 14.08, 12.65, 12.28, 15.73]])

# %%
data[59,:,:] = np.array([[33.41, 21.71, 16.3, 14.01, 11.96, 10.55, 10.78, 13.93, 19.63],
                        [27.71, 20.07, 16.75, 15.12, 13.52, 12.23, 11.29, 11.57, 15.75]])

# %%
data[60,:,:] = np.array([[33.2, 22.32, 17.15, 14.97, 12.63, 11.01, 10.94, 13.83, 18.98],
                        [27.43, 20.5, 17.13, 15.5, 13.91, 12.46, 11.32, 11.3, 14.81]])

# %%
data[61,:,:] = np.array([[34.23, 23.58, 18.06, 15.56, 13.29, 11.61, 11.48, 14.66, 20.38],
                        [28.43, 21.52, 17.96, 16.18, 14.59, 13.09, 11.72, 12.03, 15.66]])

# %%
data[62,:,:] = np.array([[41, 31.78, 26.96, 24.53, 22.15, 19.88, 17.8, 16.75, 22.26],
                        [34.13, 27.43, 23.9, 22.09, 20.34, 18.64, 17.02, 14.75, 17.34]])

# %%
data[63,:,:] = np.array([[46.72, 36.5, 31.83, 29.48, 27.17, 24.9, 22.83, 20.84, 24.37],
                        [41.67, 34.05, 30.35, 28.44, 26.54, 24.7, 22.97, 19.98, 19.55]])

# %%
data[64,:,:] = np.array([[55.1, 46.46, 42.21, 40, 37.73, 35.44, 33.19, 29.28, 27.56],
                        [50.1, 43, 39.39, 37.59, 35.81, 34.08, 32.38, 29.2, 25.14]])

# %%
data[65,:,:] = np.array([[45.42, 35.16, 30.3, 27.85, 25.53, 23.4, 21.47, 19.62, 25.05],
                        [39.81, 32.15, 28.53, 26.69, 24.92, 23.26, 21.69, 18.93, 19.9]])

# %%
data[66,:,:] = np.array([[41.67, 32.42, 28.45, 26.4, 24.34, 22.4, 20.65, 19.89, 23.94],
                        [38.08, 31.52, 28.3, 26.64, 24.98, 23.35, 21.83, 19.31, 19.03]])

# %%
data[67,:,:] = np.array([[36.61, 32.11, 28.03, 25.29, 23.21, 20.8, 18.11, 16.51, 20.19],
                        [35.22, 32.55, 29.89, 28.08, 25.92, 23.38, 20.66, 17.11, 18.62]])

# %%
data[68,:,:] = np.array([[36.39, 25.64, 20.31, 18.23, 16.57, 15.04, 14.1, 16.54, 22.11],
                        [31.57, 24.33, 20.8, 19.15, 17.62, 16.11, 14.67, 13.97, 17.1]])

# %%
data[69,:,:] = np.array([[36.25, 25.49, 19.4, 16.83, 14.69, 13.09, 13.01, 14.38, 17.13],
                        [32.25, 23.67, 19.66, 17.84, 16.23, 14.63, 13.1, 12.23, 12.84]])

# %%
data[70,:,:] = np.array([[32.71, 22.43, 17.37, 15.12, 13.02, 11.23, 10.49, 10.78, 15.11],
                        [28.81, 21.17, 17.61, 15.84, 14.26, 12.78, 11.69, 11.09, 11.59]])

# %%
data[71,:,:] = np.array([[32.18, 23.31, 18.91, 16.7, 14.63, 12.65, 12.3, 12.92, 14.01],
                        [29.59, 22.5, 19.01, 17.32, 15.65, 13.93, 12.54, 11.94, 11.99]])

# %%
data[72,:,:] = np.array([[38.27, 29.81, 25.52, 23.35, 21.24, 19.11, 17.12, 16.15, 18.49],
                        [35.78, 28.37, 24.79, 22.99, 21.13, 19.13, 17.28, 15.53, 15.37]])

# %%
data[73,:,:] = np.array([[32.94, 23.63, 19.34, 17.19, 15.12, 13.29, 12.67, 13.69, 16.53],
                        [30.39, 23.1, 19.75, 18.03, 16.34, 14.67, 13.27, 12.25, 13.25]])

# %%
data[74,:,:] = np.array([[33.45, 24.38, 20.14, 18.2, 16.35, 14.97, 14.25, 14.76, 16.4],
                        [30.28, 23.26, 19.88, 18.24, 16.69, 15.16, 13.93, 13.09, 12.59]])

# %%
data[75,:,:] = np.array([[34.12, 23.82, 18.92, 16.43, 14.31, 13.03, 12.18, 13.24, 16.44],
                        [29.8, 22.56, 19.66, 17.93, 16.21, 14.71, 13.47, 11.49, 12.03]])

# %%
data[76,:,:] = np.array([[33.43, 23.02, 17.53, 15.01, 12.97, 11.39, 11.11, 12.48, 16.03],
                        [28.48, 20.96, 17.37, 15.64, 14.07, 12.59, 11.34, 10.44, 11.88]])

# %%
data[77,:,:] = np.array([[33.5, 24.28, 20.04, 17.99, 16.21, 14.69, 14.1, 15.37, 18.92],
                        [28.98, 22.23, 18.89, 17.29, 15.81, 14.43, 13.24, 12.99, 14.28]])

# %%
data[78,:,:] = np.array([[30.96, 22.15, 17.91, 15.83, 14.04, 12.53, 12.2, 13.2, 15.23],
                        [26.05, 20.16, 17.26, 15.8, 14.43, 13.15, 12.13, 11.44, 11.85]])

# %%
data[79,:,:] = np.array([[33.78, 24.87, 20.41, 18.14, 16.09, 14.19, 12.87, 13.22, 15.28],
                        [29.24, 22.71, 19.31, 17.63, 16.07, 14.55, 13.12, 11.92, 12.08]])

# %%
data[80,:,:] = np.array([[30.81, 21.94, 16.72, 14.12, 11.96, 10.44, 10.37, 12.18, 15.71],
                        [26.48, 19.56, 15.97, 14.18, 12.59, 11.19, 10.29, 10.56, 12.2]])

# %%
data[81,:,:] = np.array([[33.72, 23.6, 17.95, 15.29, 12.77, 10.66, 10.67, 12.13, 15.65],
                        [28.12, 20.18, 16.62, 14.8, 13.09, 11.37, 10.17, 9.69, 10.22]])

# %%
data[82,:,:] = np.array([[28.78, 20.26, 15.66, 13.23, 10.77, 8.92, 9.27, 10.63, 12.54],
                        [25.26, 18.47, 15.24, 13.5, 11.76, 10.12, 9.19, 8.96, 10.77]])

# %%
data[83,:,:] = np.array([[28.86, 20.83, 16.08, 13.71, 11.47, 9.86, 10.33, 12.11, 14.57],
                        [24.7, 18.77, 15.43, 13.73, 12.04, 10.51, 9.71, 10.36, 11.8]])

# %%
data[84,:,:] = np.array([[31.82, 23.37, 18.66, 16.51, 14.33, 12.34, 11.5, 11.14, 13.96],
                        [27.24, 20.82, 17.65, 16.09, 14.48, 13.03, 11.94, 10.83, 11.64]])

# %%
data[85,:,:] = np.array([[30.68, 22.57, 18.7, 16.81, 14.78, 12.74, 11.83, 13, 16.46],
                        [27.7, 21.59, 18.54, 16.97, 15.42, 13.85, 12.5, 11.76, 12.84]])

# %%
data[86,:,:] = np.array([[26.19, 20.65, 16.21, 14.16, 12.04, 10.27, 10.4, 11.13, 13.38],
                        [23.2, 18.57, 15.62, 14.13, 12.66, 11.31, 10.2, 10, 11.4]])

# %%
data[87,:,:] = np.array([[30.1, 23.73, 19.55, 17.45, 15.35, 13.37, 12.17, 11.85, 13.09],
                        [28.15, 21.76, 18.89, 17.35, 15.79, 14.25, 12.84, 11.86, 13.3]])

# %%
data[88,:,:] = np.array([[30.25, 24.31, 19.39, 16.97, 14.64, 12.56, 11.59, 11.5, 12.46],
                        [27.7, 20.83, 17.83, 16.24, 14.47, 12.84, 11.78, 10.91, 11.07]])

# %%
data[89,:,:] = np.array([[31.75, 20.5, 15.13, 13.05, 11.08, 9.71, 9.78, 10.47, 11.32],
                        [26.37, 18.53, 15.13, 13.62, 12.19, 10.97, 10.4, 10.47, 10.61]])

# %%
data[90,:,:] = np.array([[32.53, 21.17, 15.25, 12.88, 10.8, 9.7, 10.03, 10.66, 11.31],
                        [26.39, 18.47, 14.97, 13.39, 11.87, 10.77, 10.47, 10.91, 11.43]])

# %%
data[91,:,:] = np.array([[32.7, 21.74, 15.93, 13.53, 11.48, 10.14, 10.3, 10.6, 14.64],
                        [26.95, 19.1, 14.83, 13.02, 11.78, 10.63, 9.72, 11.55, 14.16]])

# %%
data[92,:,:] = np.array([[32.29, 25.68, 20.44, 17.95, 15.46, 13.23, 12.79, 13.29, 14.54],
                        [30.14, 22.27, 18.58, 16.83, 15.11, 13.46, 12.2, 11.44, 12.22]])

# %%
data[93,:,:] = np.array([[30.96, 22.21, 16.4, 13.78, 11.46, 9.74, 9.73, 9.94, 11.3],
                        [28.2, 19.66, 15.78, 13.97, 12.21, 10.71, 10.26, 10.3, 10.96]])

# %%
data[94,:,:] = np.array([[29.86, 21.05, 16.41, 14.15, 11.76, 9.78, 9.36, 9.49, 11.02],
                        [26.62, 19.25, 15.77, 14.02, 12.23, 10.57, 9.56, 9.63, 10.89]])

# %%
data[95,:,:] = np.array([[28.34, 19.98, 15.45, 13.27, 10.99, 9.02, 8.73, 8.99, 10.61],
                        [25.85, 18.6, 15.36, 13.64, 11.9, 10.26, 9.27, 9.16, 10.42]])

# %%
data[96,:,:] = np.array([[27.41, 18.48, 13.57, 11.34, 9.44, 8.11, 7.84, 8.22, 11.05],
                        [23.92, 17.25, 14.1, 12.45, 10.88, 9.48, 8.74, 8.66, 10]])

# %%
data[97,:,:] = np.array([[30.73, 20.6, 14.76, 11.86, 9.18, 7.33, 7.4, 7.82, 11.45],
                        [25, 17.49, 13.83, 11.89, 10.09, 8.5, 7.79, 7.88, 9.34]])

# %%
data[98,:,:] = np.array([[34.81, 24.46, 19.26, 16.66, 14.15, 11.62, 10.31, 10.6, 11.19],
                        [27.81, 21.13, 17.62, 15.8, 13.99, 12.12, 10.68, 10.18, 11.07]])

# %%
data[99,:,:] = np.array([[29.81, 19.65, 14.35, 11.82, 9.37, 7.7, 7.99, 8.34, 10.91],
                        [25.81, 18.28, 14.7, 12.83, 11, 9.29, 8.54, 8.66, 10.57]])

# %%
data[100,:,:] = np.array([[33.97, 23.81, 18.99, 16.43, 13.66, 10.76, 9.65, 10.29, 11.4],
                        [28.78, 21.34, 17.68, 15.71, 13.66, 11.6, 10.1, 9.57, 9.95]])

# %%
data[101,:,:] = np.array([[31.14, 21.44, 16.5, 14.23, 11.85, 10.11, 10.22, 10.88, 11.22],
                        [27.17, 19.89, 16.47, 14.77, 12.97, 11.36, 10.62, 10.91, 11.32]])

# %%
data[102,:,:] = np.array([[32.48, 21.67, 15.73, 13.21, 10.66, 9.28, 9.85, 10.68, 11.19],
                        [27.79, 19.84, 15.83, 13.96, 12.14, 10.71, 10.28, 10.71, 11.04]])

# %%
data[103,:,:] = np.array([[37.36, 27, 21.2, 18.21, 15.24, 12.66, 11.27, 10.97, 12.9],
                        [32.56, 24.18, 19.64, 17.43, 15.25, 13.19, 11.85, 11.59, 11.95]])

# %%
data[104,:,:] = np.array([[38.53, 28.31, 23.71, 21.27, 18.73, 16.08, 14.2, 13.8, 14.2],
                        [33.31, 25.98, 22.06, 20.09, 18.13, 16.13, 14.36, 12.91, 12.94]])

# %%
data[105,:,:] = np.array([[31.18, 20.98, 15.7, 13.58, 10.97, 8.9, 8.72, 8.68, 12.11],
                        [28.7, 20.5, 16.59, 14.65, 12.59, 10.52, 9.64, 9.82, 10.39]])

# %%
data[106,:,:] = np.array([[28.82, 22.04, 18.4, 16.5, 13.8, 10.91, 9.76, 10.66, 14.27],
                        [27.91, 21.52, 18.35, 16.49, 14.34, 11.98, 10.31, 10.02, 11.14]])

# %%
data[107,:,:] = np.array([[30.6, 21.29, 17.32, 15.12, 12.9, 10.47, 9.25, 9.29, 12.3],
                        [26.96, 20.36, 17.02, 15.26, 13.53, 11.6, 9.89, 9.39, 10.42]])

# %%
data[108,:,:] = np.array([[30.01, 21.28, 17.07, 14.84, 12.12, 9.37, 8.75, 9.47, 11.66],
                        [27.06, 19.93, 16.52, 14.69, 12.59, 10.32, 8.98, 9.21, 10.03]])

# %%
data[109,:,:] = np.array([[35.46, 26, 21.4, 19.02, 15.93, 12.52, 11.02, 11.51, 13.1],
                        [30.39, 23.14, 19.6, 17.59, 15.26, 12.79, 11.07, 10.69, 11.13]])

# %%
data[110,:,:] = np.array([[27.48, 18.9, 14.49, 12.23, 10.19, 7.83, 8.48, 10.49, 12.2],
                        [25.53, 18.48, 15.25, 13.51, 11.86, 10.01, 8.56, 8.44, 9.36]])

# %%
data[111,:,:] = np.array([[44.15, 33.88, 28.75, 26.06, 23.1, 19.77, 17.12, 16.51, 17.45],
                        [38.68, 30.64, 26.31, 24.22, 22.08, 19.76, 17.45, 14.94, 15.29]])

# %%
data[112,:,:] = np.array([[38.44, 29.32, 25.94, 23.86, 21.2, 18.41, 16.31, 14.42, 15.52],
                        [33.5, 27.03, 23.72, 21.9, 19.9, 17.75, 15.84, 14.2, 14.16]])

# %%
data[113,:,:] = np.array([[31.7, 21.69, 17.17, 14.91, 12.19, 9.88, 9.82, 10.92, 11.69],
                        [28.53, 21.41, 17.78, 15.86, 13.85, 11.84, 10.78, 10.83, 10.98]])

# %%
data[114,:,:] = np.array([[32.58, 22.98, 18.67, 16.39, 13.97, 11.31, 9.93, 10.3, 11.94],
                        [29.27, 22.3, 18.69, 16.8, 14.86, 12.77, 10.96, 9.97, 10.32]])

# %%
data[115,:,:] = np.array([[34.67, 24.93, 20.57, 18.34, 15.73, 12.78, 11.24, 11.91, 12.78],
                        [30.26, 23.26, 19.71, 17.84, 15.79, 13.47, 11.55, 10.89, 11.42]])

# %%
data[116,:,:] = np.array([[33.76, 25.02, 21.57, 19.65, 17.21, 14.77, 13.43, 12.83, 14.44],
                        [31.74, 25.33, 21.83, 20.02, 18.11, 16.06, 14.35, 13.51, 13.73]])

# %%
data[117,:,:] = np.array([[34.89, 26.17, 22.39, 20.34, 18.26, 15.96, 13.91, 13.05, 13.69],
                        [32.54, 25.89, 22.51, 20.74, 18.95, 17.05, 15.13, 12.85, 12.64]])

# %%
data[118,:,:] = np.array([[31.48, 21.17, 16.53, 14.41, 12.13, 9.6, 8.8, 9.5, 11.63],
                        [27.33, 20.09, 16.6, 14.79, 12.85, 10.68, 9.15, 8.99, 9.59]])

# %%
data[119,:,:] = np.array([[32.25, 22.53, 17.95, 15.5, 13.38, 11.09, 9.82, 9.84, 11.74],
                        [29.23, 21.92, 18.26, 16.38, 14.54, 12.53, 10.77, 10.15, 10.31]])

# %%
data[120,:,:] = np.array([[30.5, 21.71, 17.17, 15.09, 12, 9.13, 9.54, 10.7, 12.75],
                        [27.65, 20.36, 16.91, 15.1, 12.78, 10.19, 8.87, 9.77, 11.06]])

# %%
data[121,:,:] = np.array([[33.52, 23.24, 18.32, 15.96, 12.92, 9.85, 9.38, 10.82, 12.1],
                        [29.17, 21.68, 17.9, 15.9, 13.52, 11.01, 9.63, 10.15, 11.18]])

# %%
data[122,:,:] = np.array([[29.04, 19.73, 14.5, 12, 9.54, 8.01, 8.6, 9.7, 11.94],
                        [26.55, 19.03, 15.15, 13.15, 11.23, 9.38, 8.71, 8.83, 9.81]])

# %%
data[123,:,:] = np.array([[31.12, 21.49, 16.57, 14.05, 11.21, 8.4, 8.33, 9.21, 11.63],
                        [26.68, 19.61, 15.9, 13.92, 11.75, 9.45, 8.2, 8.98, 11.35]])

# %%
data[124,:,:] = np.array([[29.84, 20.59, 16.19, 13.84, 11.05, 7.85, 7.74, 8.82, 11.88],
                        [27.17, 20.25, 16.74, 14.74, 12.52, 9.88, 8.32, 8.68, 10.4]])

# %%
data[125,:,:] = np.array([[32.83, 23.91, 19.45, 17.07, 14.73, 11.94, 10.08, 10.17, 11.95],
                        [29.5, 22.07, 18.43, 16.6, 14.79, 12.69, 10.71, 10.12, 10.51]])

# %%
data[126,:,:] = np.array([[30.6, 21.04, 15.83, 13.25, 11.07, 9.43, 9.18, 9.36, 11.54],
                        [26.86, 19.26, 15.41, 13.63, 11.82, 10.1, 9.43, 10.52, 12.57]])

# %%
data[127,:,:] = np.array([[31.56, 21.26, 16.23, 13.88, 11.66, 9.73, 9.76, 10.29, 10.55],
                        [26.71, 20, 15.81, 14.19, 12.55, 10.64, 10.11, 10.79, 11.27]])

# %%
data[128,:,:] = np.array([[31.3, 20.72, 14.5, 11.62, 8.95, 7.83, 8.44, 9.11, 12.88],
                        [26.61, 18.73, 14.29, 12.63, 10.89, 9.14, 9.14, 9.91, 10.43]])

# %%
data[129,:,:] = np.array([[32.04, 20.94, 14.91, 12.24, 9.95, 8.95, 9.3, 9.9, 13.9],
                        [26.65, 19.07, 15.06, 13.38, 11.49, 10.05, 9.57, 10.34, 11.14]])

# %%
data[130,:,:] = np.array([[32.13, 20.63, 14.55, 11.76, 9.4, 8.04, 8.17, 10.17, 15.88],
                        [26, 17.63, 13.53, 11.68, 9.99, 8.76, 8.29, 8.7, 11.62]])

# %%
data[131,:,:] = np.array([[31.36, 19.91, 13.6, 10.59, 7.85, 6.69, 7.34, 9.35, 15],
                        [25.51, 17.42, 13, 11.21, 9.35, 7.97, 7.82, 8.65, 9.94]])

# %%
data[132,:,:] = np.array([[30, 19.75, 13.89, 11.07, 8.09, 6.56, 7.91, 10.88, 14.58],
                        [26.2, 17.17, 13.36, 11.23, 8.97, 7.49, 7, 8.07, 9.78]])

# %%
data[133,:,:] = np.array([[29.13, 20.24, 14.45, 11.42, 8.65, 6.57, 7.03, 7.67, 10.31],
                        [26.23, 18.05, 13.85, 11.65, 9.5, 7.38, 7.19, 7.48, 9.33]])

# %%
data[134,:,:] = np.array([[29.08, 18.82, 13.8, 10.5, 7.4, 6.07, 6.66, 7.09, 9.09],
                        [25.95, 17.7, 13.39, 11.09, 8.89, 7.05, 6.73, 6.97, 8.54]])

# %%
data[135,:,:] = np.array([[29.3, 19.39, 13.85, 11.2, 8.06, 6.43, 7.28, 8.44, 11.97],
                        [26.55, 18.18, 14.31, 12.26, 9.71, 7.61, 6.87, 8.02, 9.77]])

# %%
data[136,:,:] = np.array([[27.75, 18.96, 12.67, 9.81, 6.53, 5.99, 7.55, 9.15, 11.72],
                        [24.93, 16.85, 12.62, 10.56, 8.1, 6.62, 7.14, 8.5, 9.82]])

# %%
data[137,:,:] = np.array([[29.35, 20.31, 13.07, 10.23, 7.44, 6.6, 7.52, 8.2, 9.81],
                        [26.68, 17.22, 12.53, 10.74, 8.53, 6.94, 7.76, 8.8, 9.49]])

# %%
data[138,:,:] = np.array([[30.83, 20.19, 13.89, 11.43, 8.75, 7.54, 8.44, 9.75, 12.8],
                        [26.19, 17.55, 13.36, 11.55, 9.33, 7.46, 7.57, 8.94, 10]])

# %%
data[139,:,:] = np.array([[31.96, 20.82, 13.16, 9.47, 6.72, 7.24, 7.74, 8.01, 11.13],
                        [29.05, 18, 12.5, 10.56, 8.62, 7.53, 8.21, 8.89, 9.27]])

# %%
data[140,:,:] = np.array([[31.9, 21.36, 15.75, 13.19, 11.39, 10.02, 9.88, 10.04, 13.48],
                        [26.87, 19.62, 15.31, 13.51, 11.96, 10.44, 9.81, 10.04, 10.61]])

# %%
data[141,:,:] = np.array([[39.13, 27.9, 20.71, 17.33, 14.83, 12.89, 12.35, 12.22, 14.11],
                        [33.82, 24.67, 19.48, 17.19, 15.14, 13.31, 12.31, 12.30, 12.55]])

# %%
data[142,:,:] = np.array([[34.33, 25.17, 20.66, 18.65, 16.79, 15.04, 14.28, 14.29, 15.38],
                        [31.43, 24.01, 20.37, 18.61, 16.88, 15.29, 14.14, 13.54, 13.98]])

# %%
data[143,:,:] = np.array([[32.86, 21.97, 17.1, 14.96, 13.13, 11.41, 10.68, 13.9, 21.09],
                        [28.94, 21.13, 17.56, 15.78, 14.16, 12.68, 11.46, 11.31, 16.38]])

# %%
data[144,:,:] = np.array([[33.87, 23.63, 17.07, 14.11, 11.44, 9.17, 8.92, 9.69, 10.15],
                        [28.93, 20.55, 16.09, 14.03, 11.94, 10.01, 9.12, 9.59, 10.17]])

# %%
data[145,:,:] = np.array([[32.36, 23.25, 17.42, 14.36, 12.16, 10.09, 8.47, 8.53, 9.9],
                        [29.56, 21.32, 16.73, 14.61, 12.85, 10.98, 9.15, 8.63, 9.14]])

# %%
data[146,:,:] = np.array([[33.1, 21.73, 14.61, 11.89, 9.46, 8.44, 9.21, 9.77, 11.08],
                        [28.4, 19.31, 14.21, 12.24, 10.34, 8.61, 8.91, 9.57, 9.93]])

# %%
data[147,:,:] = np.array([[35.36, 22.77, 14.72, 11.36, 9.09, 8.16, 8.56, 8.86, 10.41],
                        [28.56, 19.44, 14, 11.96, 10.27, 8.88, 8.72, 9.14, 9.41]])

# %%
data[148,:,:] = np.array([[32.86, 22.11, 14.69, 11.35, 8.78, 7.54, 8.14, 8.55, 10.79],
                        [27.69, 19.44, 14.26, 12.16, 10.3, 8.49, 8.42, 8.92, 9.49]])

# %%
data[149,:,:] = np.array([[36.64, 27.14, 22.71, 20.51, 18.4, 16.32, 14.64, 14.98, 20.67],
                        [31.61, 24.4, 21.05, 19.53, 18.1, 16.6, 15.03, 13.87, 15.64]])

# %%
data[150,:,:] = np.array([[33.01, 24.29, 20.51, 18.53, 16.33, 14.33, 13.35, 12.38, 13.9],
                        [29.57, 23.38, 20.08, 18.24, 16.37, 14.45, 13.05, 12.55, 12.7]])

# %%
data[151,:,:] = np.array([[39.12, 30.94, 27.55, 25.49, 23.18, 20.86, 19.14, 18.06, 21.41],
                        [33.7, 27.97, 25.02, 23.39, 21.77, 20.24, 18.81, 16.53, 15.37]])

# %%
data[152,:,:] = np.array([[32.93, 23.56, 18.02, 15.61, 13.66, 12.19, 11.81, 11.93, 11.95],
                        [29.09, 21.54, 17.95, 16.27, 14.67, 13.23, 12.24, 11.85, 12.04]])

# %%
data[153,:,:] = np.array([[34.07, 23.66, 17.5, 14.37, 12.05, 9.71, 9.61, 9.87, 10.52],
                        [28.29, 20.57, 16.22, 14.24, 12.47, 10.6, 9.53, 9.74, 10.38]])

# %%
data[154,:,:] = np.array([[28.85, 20.57, 16.13, 14.04, 11.61, 9.24, 9.15, 9.6, 11.28],
                        [27.11, 19.63, 16.34, 14.58, 12.69, 10.68, 9.64, 9.8, 9.97]])

# %%
data[155,:,:] = np.array([[32.76, 22.29, 16.01, 13, 10.45, 8.24, 8.71, 9.19, 12.69],
                        [27.97, 20.11, 15.39, 13.29, 11.36, 9.43, 9.26, 9.65, 10.01]])

# %%
data[156,:,:] = np.array([[32.34, 24.45, 21.04, 19.43, 17.74, 15.62, 13.58, 12.89, 13.07],
                        [28.37, 22.36, 19.7, 18.28, 16.85, 15.33, 13.72, 12.16, 12.01]])

# %%
# end of june = np.array([[32.13, 22.27, 17.55, 15.14, 12.92, 11.33, 11.18, 11.21, 13.7],
#                        [27.41, 20.98, 17.33, 15.59, 13.86, 12.16, 11.37, 11.64, 11.94]])
